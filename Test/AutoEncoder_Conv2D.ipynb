# %% [markdown]
# ## 1. 텐서플로우 메모리 관리

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        # 프로그램 시작시에 메모리 증가가 설정되어야만 합니다
        print(e)
# Out:
# 2022-08-03 01:17:40.684515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-03 01:17:40.695285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-03 01:17:40.697099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# ## 2. 패키지 로드

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Reshape, Conv2D, MaxPooling2D, Input, Conv2DTranspose
from tensorflow.keras.losses import MeanSquaredError
import numpy as np
from PIL import Image
import cv2
from glob import glob
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# ## 3. 데이터 로드

# %%
# 데이터 로드
human_image_datas = glob('./image_human/*.jpg')
webtoon_image_datas = glob('./image_webtoon/*.jpg')

# %%
# 데이터 크기 확인
len(human_image_datas), len(webtoon_image_datas)
# Out:
# (10456, 27702)

# %% [markdown]
# ## 4. 데이터 전처리

# %%
# 데이터 셋으로 합치기
data_set = [human_image_datas, webtoon_image_datas[:10456]]
X = []

for data in tqdm(data_set):
    for image_name in tqdm(data):
        image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image, (32, 32))
        ret, thres = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
        image = cv2.cvtColor(thres, cv2.COLOR_GRAY2RGB)
        X.append(image)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/10456 [00:00<?, ?it/s]
#   0%|          | 0/10456 [00:00<?, ?it/s]

# %%
# Numpy 배열로 변경
X = np.array(X)

# %%
# train data 와 test data로 나누기
train_images, test_images = train_test_split(X, test_size=0.2, shuffle=True, random_state = 41)

# %%
# 이미지 픽셀의 값을 0~1 사이의 값으로 만들기
train_images = train_images.astype(np.float32) / 255.
test_images = test_images.astype(np.float32) / 255.

# %%
# shape 확인
train_images.shape, test_images.shape
# Out:
# ((16729, 32, 32, 3), (4183, 32, 32, 3))

# %% [markdown]
# ## 5. 모델 생성

# %%
# params 설정
learning_rate = 0.01
epochs = 1000
batch_size = 32
latent_dim = 64

# %%
class AutoEncoder(Model):
    def __init__(self, latent_dim):
        super(AutoEncoder, self).__init__()
        
        self.latent_dim = latent_dim
        # 인코더 정의
        self.encoder = tf.keras.Sequential([
            Input(shape=(32, 32, 3)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D((2, 2), padding='same'),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D((2, 2), padding='same')
        ])
        
        self.decoder = tf.keras.Sequential([
            Conv2DTranspose(64, (3, 3), strides=2, activation='relu', padding='same'),
            Conv2DTranspose(64, (3, 3), strides=2, activation='relu', padding='same'),
            Conv2D(1, (3, 3), activation='sigmoid', padding='same')
        ])
        
    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)

        return decoded

# %%
autoEncoder = AutoEncoder(latent_dim)
autoEncoder.compile(optimizer='adam', loss=MeanSquaredError(), metrics=['mse'])
checkpointer = ModelCheckpoint(filepath='./models_2D/autoencoder_Conv2D_cp.ckpt', verbos=1, save_best_only=True, save_weights_only=True, monitor='val_mse', mode='min')
earlystopping = EarlyStopping(monitor='val_mse', mode='min', verbose=1, patience=20)

# %% [markdown]
# ## 6. 모델 학습

# %%
history = autoEncoder.fit(train_images, train_images,
                epochs=epochs,
                shuffle=True,
                validation_data=(test_images, test_images), workers=2, callbacks=[checkpointer, earlystopping], batch_size=batch_size)
# Out:
# 2022-08-03 01:21:35.478381: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 205565952 exceeds 10% of free system memory.
# 2022-08-03 01:21:35.693134: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 205565952 exceeds 10% of free system memory.
# 2022-08-03 01:21:35.928808: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 205565952 exceeds 10% of free system memory.
# 2022-08-03 01:21:36.075263: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 205565952 exceeds 10% of free system memory.
# Epoch 1/1000
# 2022-08-03 01:21:38.601640: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8201
# 2022-08-03 01:21:40.793581: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 523/523 [==============================] - ETA: 0s - loss: 0.0570 - mse: 0.0570
# 2022-08-03 01:21:52.956336: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 51400704 exceeds 10% of free system memory.
# 523/523 [==============================] - 18s 20ms/step - loss: 0.0570 - mse: 0.0570 - val_loss: 0.0342 - val_mse: 0.0342
# Epoch 2/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0268 - mse: 0.0268 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 3/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 4/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 5/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 6/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 7/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 8/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 9/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 10/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 11/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 12/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 13/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 14/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 15/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 16/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 17/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 18/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 19/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 20/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 21/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 22/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 23/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 24/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 25/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 26/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 27/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 28/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 29/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 30/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 31/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 32/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 33/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 9.9003e-04 - mse: 9.9003e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 34/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 9.5705e-04 - mse: 9.5705e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 35/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 9.1155e-04 - mse: 9.1155e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 36/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 8.8609e-04 - mse: 8.8609e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 37/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 8.5883e-04 - mse: 8.5883e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 38/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 8.2033e-04 - mse: 8.2033e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 39/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 8.0375e-04 - mse: 8.0375e-04 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 40/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 7.6749e-04 - mse: 7.6749e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 41/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 7.8339e-04 - mse: 7.8339e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 42/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 7.4107e-04 - mse: 7.4107e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 43/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 6.9877e-04 - mse: 6.9877e-04 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 44/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 7.0316e-04 - mse: 7.0316e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 45/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 6.8298e-04 - mse: 6.8298e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 46/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 6.8540e-04 - mse: 6.8540e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 47/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 6.5073e-04 - mse: 6.5073e-04 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 48/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 6.3548e-04 - mse: 6.3548e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 49/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 6.3028e-04 - mse: 6.3028e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 50/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 6.2336e-04 - mse: 6.2336e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 51/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 5.7091e-04 - mse: 5.7091e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 52/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 5.8380e-04 - mse: 5.8380e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 53/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 5.8353e-04 - mse: 5.8353e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 54/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 5.6708e-04 - mse: 5.6708e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 55/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 5.1791e-04 - mse: 5.1791e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 56/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 5.7101e-04 - mse: 5.7101e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 57/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 5.5157e-04 - mse: 5.5157e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 58/1000
# 523/523 [==============================] - 4s 8ms/step - loss: 5.4051e-04 - mse: 5.4051e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 59/1000
# 523/523 [==============================] - 7s 13ms/step - loss: 5.0861e-04 - mse: 5.0861e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 60/1000
# 523/523 [==============================] - 8s 15ms/step - loss: 5.1883e-04 - mse: 5.1883e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 61/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 5.1452e-04 - mse: 5.1452e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 62/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 5.0109e-04 - mse: 5.0109e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 63/1000
# 523/523 [==============================] - 9s 16ms/step - loss: 4.7675e-04 - mse: 4.7675e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 64/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.8208e-04 - mse: 4.8208e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 65/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.6364e-04 - mse: 4.6364e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 66/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.9433e-04 - mse: 4.9433e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 67/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.7241e-04 - mse: 4.7241e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 68/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 4.5808e-04 - mse: 4.5808e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 69/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.8357e-04 - mse: 4.8357e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 70/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.6387e-04 - mse: 4.6387e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 71/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.5302e-04 - mse: 4.5302e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 72/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 4.6502e-04 - mse: 4.6502e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 73/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.1350e-04 - mse: 4.1350e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 74/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.5635e-04 - mse: 4.5635e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 75/1000
# 523/523 [==============================] - 9s 17ms/step - loss: 4.2596e-04 - mse: 4.2596e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 76/1000
# 523/523 [==============================] - 8s 16ms/step - loss: 4.3592e-04 - mse: 4.3592e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 00076: early stopping

# %% [markdown]
# ## 7. 평가 : 재구성 오류 (MSE)로 확인

# %%
import pandas as pd

# %%
history_eval = autoEncoder.evaluate(test_images, test_images)
plt.plot(pd.DataFrame(history.history))
plt.show()
# Out:
# 131/131 [==============================] - 1s 6ms/step - loss: 0.0011 - mse: 0.0011

# %% [markdown]
# ## 8. 예측 및 테스트

# %%
encoded_imgs = autoEncoder.encoder(test_images[:100]).numpy()
decoded_imgs = autoEncoder.decoder(encoded_imgs).numpy()

# %%
encoded_imgs.shape, decoded_imgs.shape
# Out:
# ((100, 8, 8, 64), (100, 32, 32, 1))

# %%
n = 10

plt.figure(figsize=(2 * 10, 5))

for i in range(10):
    ax = plt.subplot(2, n, i+1)
    plt.imshow(test_images[i])
    plt.title('original')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i])
    plt.title('reconstructed')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ## 모델 로드

# %%
load_model = AutoEncoder(64)

# %%
load_model.load_weights('./models_2D/autoencoder_Conv2D_cp.ckpt')

# %%
load_model.compile(optimizer='adam', loss=MeanSquaredError(), metrics=['mse'])

# %%
load_model.evaluate(test_images, test_images)
# Out:
# 131/131 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011
# [0.0011136133689433336, 0.0011136133689433336]
