# %% [markdown]
# ## 1. 패키지 로드

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## 2. 파일 로드

# %%
actors_df = pd.read_csv('Actor_namuwiki.csv', encoding='utf-8-sig')
actors_df.head(3)
# Out:
#   Name                                         Name_url birth_year  \
# 0  감우성  https://namu.wiki/w/%EA%B0%90%EC%9A%B0%EC%84%B1      1970년
# 1  강경준  https://namu.wiki/w/%EA%B0%95%EA%B2%BD%EC%A4%80      1983년
# 2  강기영  https://namu.wiki/w/%EA%B0%95%EA%B8%B0%EC%98%81      1983년
#
#                                   activation_content
# 0  MBC 20기 공채 탤런트로 배우 생활을 시작했으며 동기로 한석규, 박철, 차광수,...
# 1  초등학교 시절에는 야구, 중학교 시절에는 농구선수였었다. 농구를 소재로 한 드라마 ...
# 2  tvN 드라마 고교처세왕, 오 나의 귀신님에서 감초역할로 등장하며 이름을 알렸다. ...

# %% [markdown]
# ## 3. 전처리

# %% [markdown]
# ### 1) Name 전처리

# %%
actors_df['Name'] = actors_df.Name.str.replace('[^가-힣]', '') # 한글을 제외하고 모두 제거
actors_df.head(3)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19448\1301567671.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   actors_df['Name'] = actors_df.Name.str.replace('[^가-힣]', '') # 한글을 제외하고 모두 제거
#   Name                                         Name_url birth_year  \
# 0  감우성  https://namu.wiki/w/%EA%B0%90%EC%9A%B0%EC%84%B1      1970년
# 1  강경준  https://namu.wiki/w/%EA%B0%95%EA%B2%BD%EC%A4%80      1983년
# 2  강기영  https://namu.wiki/w/%EA%B0%95%EA%B8%B0%EC%98%81      1983년
#
#                                   activation_content
# 0  MBC 20기 공채 탤런트로 배우 생활을 시작했으며 동기로 한석규, 박철, 차광수,...
# 1  초등학교 시절에는 야구, 중학교 시절에는 농구선수였었다. 농구를 소재로 한 드라마 ...
# 2  tvN 드라마 고교처세왕, 오 나의 귀신님에서 감초역할로 등장하며 이름을 알렸다. ...

# %%
actors_df = actors_df.dropna(subset='Name')

# %% [markdown]
# ### 2) birth_year -> age 파생변수 만들기

# %%
# 1. birth_year에 null 값이 존재하면 제거
actors_df = actors_df.dropna(subset='birth_year')
actors_df.head(2)
# Out:
#   Name                                         Name_url birth_year  \
# 0  감우성  https://namu.wiki/w/%EA%B0%90%EC%9A%B0%EC%84%B1      1970년
# 1  강경준  https://namu.wiki/w/%EA%B0%95%EA%B2%BD%EC%A4%80      1983년
#
#                                   activation_content
# 0  MBC 20기 공채 탤런트로 배우 생활을 시작했으며 동기로 한석규, 박철, 차광수,...
# 1  초등학교 시절에는 야구, 중학교 시절에는 농구선수였었다. 농구를 소재로 한 드라마 ...

# %%
# 2. Age 추출하여 파생변수 생성
def extract_age(x):
    x = re.sub('[^0-9]', '', x)
    if x:
        x = 2022 - int(x)
    else: # 전처리 결과 아무것도 남지 않았다면 null 값으로 채움
        x = np.nan
    
    return x

actors_df['Age'] = actors_df.birth_year.apply(extract_age)
actors_df.head(2)
# Out:
#   Name                                         Name_url birth_year  \
# 0  감우성  https://namu.wiki/w/%EA%B0%90%EC%9A%B0%EC%84%B1      1970년
# 1  강경준  https://namu.wiki/w/%EA%B0%95%EA%B2%BD%EC%A4%80      1983년
#
#                                   activation_content   Age
# 0  MBC 20기 공채 탤런트로 배우 생활을 시작했으며 동기로 한석규, 박철, 차광수,...  52.0
# 1  초등학교 시절에는 야구, 중학교 시절에는 농구선수였었다. 농구를 소재로 한 드라마 ...  39.0

# %%
# 3. Age에 null 값 존재하면 제거
actors_df = actors_df.dropna(subset='Age')

# %%
# 4. Age의 type을 int형으로 변경
actors_df['Age'] = actors_df.Age.astype(int)
actors_df.head(3)
# Out:
#   Name                                         Name_url birth_year  \
# 0  감우성  https://namu.wiki/w/%EA%B0%90%EC%9A%B0%EC%84%B1      1970년
# 1  강경준  https://namu.wiki/w/%EA%B0%95%EA%B2%BD%EC%A4%80      1983년
# 2  강기영  https://namu.wiki/w/%EA%B0%95%EA%B8%B0%EC%98%81      1983년
#
#                                   activation_content  Age
# 0  MBC 20기 공채 탤런트로 배우 생활을 시작했으며 동기로 한석규, 박철, 차광수,...   52
# 1  초등학교 시절에는 야구, 중학교 시절에는 농구선수였었다. 농구를 소재로 한 드라마 ...   39
# 2  tvN 드라마 고교처세왕, 오 나의 귀신님에서 감초역할로 등장하며 이름을 알렸다. ...   39

# %% [markdown]
# ## 4. Name, Age, activation_content의 열만 가진 df 생성 및 성별 표시

# %%
# 1. Name, Age, activation_content 열만 가진 df 생성
save_df = actors_df[['Name', 'Age', 'activation_content']]
save_df.head(3)
# Out:
#   Name  Age                                 activation_content
# 0  감우성   52  MBC 20기 공채 탤런트로 배우 생활을 시작했으며 동기로 한석규, 박철, 차광수,...
# 1  강경준   39  초등학교 시절에는 야구, 중학교 시절에는 농구선수였었다. 농구를 소재로 한 드라마 ...
# 2  강기영   39  tvN 드라마 고교처세왕, 오 나의 귀신님에서 감초역할로 등장하며 이름을 알렸다. ...

# %%
save_df = save_df.reset_index(drop=True)

# %%
save_df['Sex'] = np.nan

# %%
save_df['Sex'][:394] = '남'
save_df['Sex'][394:] = '여'
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19448\27332688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   save_df['Sex'][:394] = '남'

# %%
# 배우, 신화, 년월, 코미디언, 가수, 인피니트, 멀티엔터테이너, 룰라
save_df.Name.to_list()
# Out:
# ['감우성',
#  '강경준',
#  '강기영',
#  '강남길',
#  '강동원',
#  '강성훈배우',
#  '강은탁',
#  '강이석',
#  '강정우배우',
#  '강지섭',
#  '강훈배우',
#  '고수배우',
#  '고우림',
#  '고윤',
#  '고주원',
#  '고창석',
#  '공형진',
#  '구교환',
#  '곽도원',
#  '곽동연',
#  '곽정욱',
#  '구자성',
#  '권오중',
#  '권해성',
#  '권해효',
#  '권혁수배우',
#  '권현상',
#  '권화운',
#  '김강훈',
#  '김광규배우',
#  '김기방',
#  '김기천',
#  '김남길',
#  '김도윤배우',
#  '김동완신화',
#  '김동욱배우',
#  '김동희',
#  '김동희',
#  '김명곤',
#  '김명민',
#  '김명수배우',
#  '엘인피니트',
#  '김무생',
#  '김민규배우',
#  '김민기년월',
#  '김민석배우',
#  '김민수배우',
#  '김민식배우',
#  '김민재',
#  '김민종',
#  '김병세',
#  '김산호배우',
#  '김상중',
#  '김상호배우',
#  '김선호',
#  '김성수배우',
#  '김성오',
#  '김수로배우',
#  '김수현배우',
#  '김승우',
#  '김시후',
#  '김영광배우',
#  '김영대배우',
#  '김영준배우',
#  '김영철배우',
#  '김영훈배우',
#  '김용건',
#  '김윤석',
#  '김일우',
#  '김재영배우',
#  '김재원배우',
#  '김정학',
#  '김정현',
#  '김종구',
#  '김주혁',
#  '김준',
#  '김지석배우',
#  '김지훈배우',
#  '김진규배우',
#  '김진수코미디언',
#  '김진우배우',
#  '김진엽',
#  '김찬우배우',
#  '김창완',
#  '김형묵',
#  '김형민배우',
#  '김흥수배우',
#  '김희원배우',
#  '나인우',
#  '나윤찬',
#  '남궁민',
#  '남궁원',
#  '남다름',
#  '남주혁',
#  '노종현',
#  '노주현',
#  '노형욱배우',
#  '도상우',
#  '독고영재',
#  '류경수배우',
#  '류담',
#  '류수영',
#  '류승범',
#  '류진배우',
#  '문성근',
#  '문우진',
#  '에릭신화',
#  '문태유',
#  '문지후',
#  '박강현',
#  '박건우',
#  '박광현',
#  '박근형',
#  '박동빈',
#  '박민수배우',
#  '박민우배우',
#  '박보검',
#  '박성웅',
#  '박성훈배우',
#  '박수영배우',
#  '박신양',
#  '박용우',
#  '박인환배우',
#  '박정우배우',
#  '박준목',
#  '박지빈',
#  '박지훈',
#  '박진우',
#  '박해수',
#  '박해일',
#  '박해진',
#  '박혁권',
#  '박형식',
#  '박희순',
#  '배성우',
#  '배용준',
#  '백도빈',
#  '백서빈',
#  '백성현',
#  '백윤식',
#  '백일섭',
#  '변요한',
#  '변희봉',
#  '봉태규',
#  '서강준',
#  '서우진',
#  '서인석',
#  '서지석',
#  '서하준',
#  '선동혁',
#  '선우재덕',
#  '설경구',
#  '성동일',
#  '손석구',
#  '손유동',
#  '손창민',
#  '손현주',
#  '송강호',
#  '송건희',
#  '송새벽',
#  '송승헌',
#  '송승환',
#  '송일국',
#  '송재림',
#  '송재호',
#  '송중기',
#  '신동욱배우',
#  '신성일',
#  '신이안배우',
#  '신재하',
#  '신하균',
#  '심지호배우',
#  '심형탁',
#  '안보현',
#  '안석환',
#  '안성기',
#  '데니안',
#  '안우연',
#  '안은호배우',
#  '안재모',
#  '안재욱',
#  '안재환',
#  '안재영',
#  '안재홍배우',
#  '안효섭',
#  '양동근',
#  '양병열',
#  '양승리',
#  '양세종배우',
#  '엄기준',
#  '엄태구',
#  '엄태웅',
#  '여진구',
#  '연규진',
#  '연정훈',
#  '연제욱',
#  '오달수',
#  '오대환',
#  '오민석',
#  '오승윤',
#  '오정세',
#  '오지명',
#  '오한결',
#  '오현경',
#  '옹성우',
#  '우도환',
#  '원우준',
#  '유동근',
#  '데프콘가수',
#  '유오성',
#  '유인촌',
#  '유주원',
#  '유준상',
#  '유준서배우',
#  '유지태',
#  '유태웅',
#  '유해진',
#  '육성재',
#  '윤계상',
#  '윤기원배우',
#  '윤다훈',
#  '윤문식',
#  '윤소호',
#  '윤승원배우',
#  '윤시윤',
#  '윤종훈',
#  '윤찬영',
#  '위하준',
#  '음문석',
#  '이광수',
#  '이규성배우',
#  '이규한',
#  '이규형배우',
#  '이기영배우',
#  '이낙훈',
#  '이덕화',
#  '이동건',
#  '이동욱',
#  '이동준',
#  '이동휘배우',
#  '이명호배우',
#  '이명훈',
#  '이민기',
#  '이민우배우',
#  '이범수',
#  '이병헌',
#  '이상엽',
#  '이상우배우',
#  '이상윤배우',
#  '이상이',
#  '이서진',
#  '이성열인피니트',
#  '이세창',
#  '이수혁배우',
#  '이순재',
#  '이승기',
#  '이승효',
#  '이승우',
#  '문태유',
#  '이승준배우',
#  '이승현',
#  '이시강',
#  '이시언',
#  '이신영',
#  '이영후',
#  '이완배우',
#  '이용주배우',
#  '이원종',
#  '이유진',
#  '이이경',
#  '이장우배우',
#  '이재룡',
#  '이정진',
#  '이종석배우',
#  '이종원',
#  '이종혁배우',
#  '이종현가수',
#  '이주승',
#  '이주원',
#  '이준배우',
#  '이준혁',
#  '이중옥',
#  '이지훈멀티엔터테이너',
#  '이지훈',
#  '이진수배우',
#  '이진욱',
#  '이창욱배우',
#  '이필모',
#  '이해우',
#  '이혁재',
#  '이호원',
#  '이호철배우',
#  '이희준',
#  '인교진',
#  '임강성',
#  '임슬옹',
#  '임시완',
#  '임원희',
#  '임창정',
#  '임채무',
#  '임하룡',
#  '임현식',
#  '임형준',
#  '장근석',
#  '장동건',
#  '장성원배우',
#  '장세진',
#  '장승조',
#  '장용',
#  '장혁',
#  '전노민',
#  '전배수',
#  '전진서',
#  '정겨운',
#  '정건주',
#  '정경호',
#  '정기섭',
#  '정링컨',
#  '정민배우',
#  '정보석',
#  '정상훈',
#  '정석원배우',
#  '정용화',
#  '정우혁배우',
#  '정웅인',
#  '정재용',
#  '정준하',
#  '비연예인',
#  '정진운',
#  '정준원',
#  '정한용',
#  '정해인',
#  '정호근',
#  '정휘',
#  '조권',
#  '조동혁',
#  '조병규배우',
#  '조원희배우',
#  '조윤우',
#  '조인성',
#  '조진웅',
#  '조형기',
#  '조희봉',
#  '주원',
#  '주진모',
#  '주현',
#  '지윤호',
#  '지성배우',
#  '지창욱',
#  '지현우',
#  '진태현',
#  '차광수',
#  '차승원',
#  '차인표',
#  '차태현',
#  '채상우',
#  '천호진',
#  '최대철',
#  '최덕문',
#  '최로운',
#  '최무성',
#  '최민수',
#  '최불암',
#  '최성재',
#  '최성준배우',
#  '최수종',
#  '최승훈',
#  '최원홍',
#  '최윤제',
#  '최재원배우',
#  '최정원',
#  '최제우배우',
#  '최준용배우',
#  '최지호배우',
#  '최진영',
#  '최태준',
#  '탕준상',
#  '한상진',
#  '한석규',
#  '한주완',
#  '한지상',
#  '한진희',
#  '허기호배우',
#  '허성태',
#  '현봉식',
#  '현빈',
#  '현우배우',
#  '홍동영',
#  '홍석천',
#  '홍성우',
#  '홍일권',
#  '홍종현',
#  '홍태의',
#  '황동주',
#  '강다현배우',
#  '강두리',
#  '강리나',
#  '강문영',
#  '강민경',
#  '강민아',
#  '강부자',
#  '강성아',
#  '강성연',
#  '강소라',
#  '강수진배우',
#  '강예원',
#  '강은아배우',
#  '강지영',
#  '강혜정',
#  '경수진',
#  '강세정',
#  '고나희',
#  '고두심',
#  '고민시',
#  '고성희',
#  '고소영',
#  '고아성',
#  '고원희',
#  '고윤정',
#  '고은미',
#  '고은아',
#  '고은아',
#  '고준희',
#  '고현정',
#  '공효진',
#  '구재이',
#  '구하진',
#  '권세은',
#  '금보라',
#  '김가연',
#  '김가은년월',
#  '김가은년월',
#  '김고은',
#  '김국희',
#  '김규리년월',
#  '김규리',
#  '김나운',
#  '김남주',
#  '김남주',
#  '김다미',
#  '김다솜',
#  '김단우',
#  '김리배우',
#  '김미경',
#  '김민희',
#  '김민희',
#  '김보경',
#  '김보민',
#  '김보연',
#  '김부선',
#  '김사랑',
#  '김새벽',
#  '김서연배우',
#  '김선아',
#  '김선영배우',
#  '김성은',
#  '김세정',
#  '김소연배우',
#  '김소현',
#  '김소현',
#  '김솔비',
#  '김수미',
#  '김수안',
#  '김수인배우',
#  '수현배우',
#  '김슬기',
#  '김시아',
#  '김아중',
#  '김여진',
#  '김예원배우',
#  '김용지',
#  '김유리',
#  '김윤진',
#  '김을동',
#  '김이지',
#  '김자옥',
#  '김재화',
#  '김정은배우',
#  '김지미',
#  '김지민배우',
#  '김지수배우',
#  '김지영',
#  '김지우배우',
#  '김지은',
#  '김지현룰라',
#  '김청',
#  '김태리',
#  '김태희',
#  '김하경배우',
#  '김하늘',
#  '김해숙',
#  '김현수배우',
#  '김혜수',
#  '김혜옥',
#  '김혜은',
#  '김혜자',
#  '김혜진배우',
#  '김환희',
#  '김효진배우',
#  '김희선',
#  '김희애',
#  '김희정',
#  '나문희',
#  '나혜미',
#  '남규리',
#  '남상미',
#  '남지현',
#  '노윤서',
#  '노현희',
#  '라미란',
#  '랑연',
#  '류현경',
#  '류혜영',
#  '류화영',
#  '명세빈',
#  '문숙',
#  '문정숙',
#  '민도희',
#  '민채은',
#  '박경혜배우',
#  '박명신',
#  '박민하',
#  '박선아',
#  '박선영',
#  '박선영',
#  '박세영',
#  '',
#  '박소담',
#  '박소현배우',
#  '조이',
#  '박수진',
#  '박시은',
#  '박신혜',
#  '박아인',
#  '박연수',
#  '박예린',
#  '박예진',
#  '박원숙',
#  '박은빈',
#  '박정수배우',
#  '박정아',
#  '박주현배우',
#  '박지영',
#  '박지예',
#  '박지현배우',
#  '박초롱',
#  '박하나',
#  '박한별',
#  '박해원',
#  '박현숙배우',
#  '박효주',
#  '박희본',
#  '방민아',
#  '배누리',
#  '배다빈',
#  '배슬기',
#  '백수민',
#  '변정수',
#  '사미자',
#  '서영배우',
#  '서영희',
#  '서예지',
#  '서우',
#  '서이수',
#  '서지혜배우',
#  '서하배우',
#  '서효림',
#  '선우선',
#  '선우용여',
#  '선우은숙',
#  '설인아',
#  '성유나',
#  '성유리',
#  '성현아',
#  '소유진',
#  '소이현',
#  '손나은',
#  '손담비',
#  '손숙',
#  '손여은',
#  '손예진',
#  '손유경',
#  '손태영',
#  '송예빈',
#  '송옥숙',
#  '송윤아',
#  '송은영',
#  '송지현배우',
#  '송지효',
#  '송하윤',
#  '송혜교',
#  '수애',
#  '신도현',
#  '신민아',
#  '신세경',
#  '신소율',
#  '신신애',
#  '신애라',
#  '신은수',
#  '신은정',
#  '신이배우',
#  '신지수배우',
#  '신지연배우',
#  '신현빈',
#  '심은경',
#  '심은우',
#  '심은진',
#  '심은하',
#  '심혜진',
#  '안문숙',
#  '안연홍',
#  '안은진',
#  '안혜경',
#  '양서현',
#  '양정아',
#  '양혜지',
#  '양희경',
#  '엄앵란',
#  '엄정화',
#  '엄지원',
#  '여운계',
#  '염정아',
#  '예지원',
#  '오미희',
#  '오소현',
#  '오아린',
#  '오아연',
#  '오연서',
#  '오연수',
#  '오영실',
#  '오하영',
#  '오현경',
#  '오혜원',
#  '옥자연',
#  '옥주현',
#  '왕빛나',
#  '우다비',
#  '원미경',
#  '유선배우',
#  '유연지',
#  '유인나',
#  '유인영',
#  '유지인',
#  '유진',
#  '유호정',
#  '윤미라',
#  '윤보라',
#  '윤보미',
#  '윤아정',
#  '윤은혜',
#  '윤정희',
#  '윤정희',
#  '윤주희',
#  '이경진',
#  '이고은',
#  '이나윤',
#  '이다인',
#  '이다연배우',
#  '이다해',
#  '이덕희배우',
#  '이루안',
#  '이미영',
#  '이민영',
#  '이민지배우',
#  '이보영',
#  '이보희배우',
#  '이성경',
#  '이솜',
#  '이수경',
#  '이수경',
#  '이숙배우',
#  '이시아배우',
#  '이엘',
#  '이엘리야',
#  '이열음',
#  '이영애',
#  '이영은',
#  '이예림',
#  '이경규',
#  '이요원',
#  '이유담',
#  '이유리배우',
#  '이유미배우',
#  '이유영',
#  '이윤미',
#  '이윤지',
#  '이응경',
#  '이자인',
#  '이재은',
#  '이정은',
#  '이정은',
#  '이정현멀티엔터테이너',
#  '이주연배우',
#  '이주영배우',
#  '이지아',
#  '이지현',
#  '이지현년월',
#  '이진',
#  '이채영',
#  '이청아',
#  '이태란',
#  '이하늬',
#  '이현경배우',
#  '혜리',
#  '이혜영',
#  '이희진배우',
#  '임수정',
#  '임수향',
#  '임예진',
#  '임유빈',
#  '임정은',
#  '장가현',
#  '장나라',
#  '장미희',
#  '장서희',
#  '장신영',
#  '장영남',
#  '장유빈',
#  '장진영배우',
#  '장하경',
#  '장혜진배우',
#  '장희령',
#  '장희진',
#  '전도연',
#  '전미선',
#  '전소민',
#  '전수경',
#  '전인화',
#  '전종서',
#  '전혜빈',
#  '전혜진',
#  '전혜진',
#  '전효성',
#  '정라엘',
#  '정려원',
#  '정보민',
#  '정소민',
#  '정수영배우',
#  '정시아',
#  '정애리배우',
#  '정애연',
#  '정예서',
#  '정예진',
#  '정은지',
#  '정은채',
#  '정인선',
#  '정주연',
#  '정혜선배우',
#  '정혜성',
#  '정혜영',
#  '정혜원배우',
#  '정혜인',
#  '조수민',
#  '조수향',
#  '조아영배우',
#  '조우리',
#  '조은숙',
#  '주민경',
#  '진경배우',
#  '진기주',
#  '진서연',
#  '진세연',
#  '진희경',
#  '차청화',
#  '차화연',
#  '차희주배우',
#  '채수빈',
#  '채수아',
#  '채시라',
#  '채영인',
#  '채정안',
#  '천샘',
#  '천우희',
#  '천희주',
#  '최강희배우',
#  '최리배우',
#  '최명길배우',
#  '최송현',
#  '최예빈배우',
#  '최윤영',
#  '최은지배우',
#  '최정원',
#  '최정원',
#  '최정윤배우',
#  '최지수배우',
#  '최지혜배우',
#  '최진실',
#  '최희서',
#  '추소영',
#  '추예진',
#  '추자현',
#  '표예진',
#  '하연수',
#  '하연주',
#  '하유미',
#  '하윤경',
#  '하지원',
#  '하희라',
#  '한가인',
#  '한보름',
#  '한선화',
#  '한수아배우',
#  '한예슬',
#  '한유진배우',
#  '한이수배우',
#  '한지현배우',
#  '한채아',
#  '한채영',
#  '한혜숙',
#  '한혜진배우',
#  '한효주',
#  '현영',
#  '홍세미',
#  '홍수아',
#  '홍수현',
#  '홍승희',
#  '홍은희',
#  '홍지민',
#  '황영희',
#  '황우슬혜',
#  '황정음']

# %%
def remove_word(x):
    x = x.rstrip('배우')
    x = x.rstrip('신화')
    x = x.rstrip('년월')
    x = x.rstrip('코미디언')
    x = x.rstrip('가수')
    x = x.rstrip('인피니트')
    x = x.rstrip('멀티엔터테이너')
    x = x.rstrip('룰라')
    
    if x:
        pass
    else:
        x = np.nan
    
    return x
save_df['Name'] = save_df.Name.apply(remove_word)

# %%
save_df = save_df.dropna(subset='Name')
save_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820 entries, 0 to 820
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                820 non-null    object
#  1   Age                 820 non-null    int32
#  2   activation_content  477 non-null    object
#  3   Sex                 820 non-null    object
# dtypes: int32(1), object(3)
# memory usage: 28.8+ KB

# %%
# 2. df 저장
save_df.to_csv('Actor_namuwiki_clean.csv', encoding='utf-8-sig', index=False)
